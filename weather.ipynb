# %%
import pandas as pd

# %%
weather = pd.read_csv("Data.csv", index_col="DATE")

# %%
weather
# Out:
#                 STATION                   NAME  AWND  FMTM  PGTM  PRCP  PSUN  \
# DATE
# 1996-07-01  USW00003936  MANHATTAN ASOS, KS US   NaN   NaN   NaN   NaN   NaN
# 1996-07-02  USW00003936  MANHATTAN ASOS, KS US   NaN   NaN   NaN   NaN   NaN
# 1996-07-03  USW00003936  MANHATTAN ASOS, KS US   NaN   NaN   NaN   NaN   NaN
# 1996-07-04  USW00003936  MANHATTAN ASOS, KS US   NaN   NaN   NaN   NaN   NaN
# 1996-07-05  USW00003936  MANHATTAN ASOS, KS US   NaN   NaN   NaN   NaN   NaN
# ...                 ...                    ...   ...   ...   ...   ...   ...
# 2023-06-27  USW00003936  MANHATTAN ASOS, KS US  6.71   NaN   NaN  0.03   NaN
# 2023-06-28  USW00003936  MANHATTAN ASOS, KS US  6.04   NaN   NaN  0.00   NaN
# 2023-06-29  USW00003936  MANHATTAN ASOS, KS US  6.93   NaN   NaN  0.00   NaN
# 2023-06-30  USW00003936  MANHATTAN ASOS, KS US  7.38   NaN   NaN  0.48   NaN
# 2023-07-01  USW00003936  MANHATTAN ASOS, KS US  5.14   NaN   NaN  0.12   NaN
#
#             SNOW  SNWD  TAVG  ...  WT07  WT08  WT09  WT10  WT13  WT16  WT17  \
# DATE                          ...
# 1996-07-01   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1996-07-02   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1996-07-03   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1996-07-04   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1996-07-05   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...  ...   ...   ...   ...   ...   ...   ...   ...
# 2023-06-27   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 2023-06-28   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 2023-06-29   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 2023-06-30   NaN   NaN   NaN  ...   NaN   1.0   NaN   NaN   NaN   NaN   NaN
# 2023-07-01   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
#             WT18  WT19  WT22
# DATE
# 1996-07-01   NaN   NaN   NaN
# 1996-07-02   NaN   NaN   NaN
# 1996-07-03   NaN   NaN   NaN
# 1996-07-04   NaN   NaN   NaN
# 1996-07-05   NaN   NaN   NaN
# ...          ...   ...   ...
# 2023-06-27   NaN   NaN   NaN
# 2023-06-28   NaN   NaN   NaN
# 2023-06-29   NaN   NaN   NaN
# 2023-06-30   NaN   NaN   NaN
# 2023-07-01   NaN   NaN   NaN
#
# [9846 rows x 33 columns]

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# STATION    0.000000
# NAME       0.000000
# AWND       0.111314
# FMTM       0.710542
# PGTM       0.546516
# PRCP       0.069165
# PSUN       0.999391
# SNOW       0.999898
# SNWD       0.999492
# TAVG       0.730043
# TMAX       0.003352
# TMIN       0.003758
# TSUN       0.999391
# WDF2       0.111416
# WDF5       0.112330
# WSF2       0.111416
# WSF5       0.112127
# WT01       0.784887
# WT02       0.975015
# WT03       0.923827
# WT04       0.999898
# WT05       0.999695
# WT06       0.997359
# WT07       0.999898
# WT08       0.914788
# WT09       0.999594
# WT10       0.999898
# WT13       0.988930
# WT16       0.989437
# WT17       0.999695
# WT18       0.997867
# WT19       0.999492
# WT22       0.999187
# dtype: float64

# %%
core_weather= weather[["PRCP","SNOW","SNWD","TMAX","TMIN"]].copy()

# %%
core_weather.columns = ["precip","snow","snow_depth","temp_max","temp_min"]

# %%
core_weather
# Out:
#             precip  snow  snow_depth  temp_max  temp_min
# DATE
# 1996-07-01     NaN   NaN         NaN      98.0      66.0
# 1996-07-02     NaN   NaN         NaN     100.0      66.0
# 1996-07-03     NaN   NaN         NaN      92.0      67.0
# 1996-07-04     NaN   NaN         NaN      88.0      68.0
# 1996-07-05     NaN   NaN         NaN      91.0      65.0
# ...            ...   ...         ...       ...       ...
# 2023-06-27    0.03   NaN         NaN      90.0      61.0
# 2023-06-28    0.00   NaN         NaN     103.0      71.0
# 2023-06-29    0.00   NaN         NaN      98.0      74.0
# 2023-06-30    0.48   NaN         NaN      97.0      70.0
# 2023-07-01    0.12   NaN         NaN      88.0      66.0
#
# [9846 rows x 5 columns]

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip        0.069165
# snow          0.999898
# snow_depth    0.999492
# temp_max      0.003352
# temp_min      0.003758
# dtype: float64

# %%
core_weather["snow"].value_counts()
# Out:
# 0.0    1
# Name: snow, dtype: int64

# %%
del core_weather["snow"]

# %%
core_weather["snow_depth"].value_counts()
# Out:
# 0.0    5
# Name: snow_depth, dtype: int64

# %%
del core_weather["snow_depth"]

# %%
core_weather[pd.isnull(core_weather["precip"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1996-07-01     NaN      98.0      66.0
# 1996-07-02     NaN     100.0      66.0
# 1996-07-03     NaN      92.0      67.0
# 1996-07-04     NaN      88.0      68.0
# 1996-07-05     NaN      91.0      65.0
# ...            ...       ...       ...
# 2021-08-10     NaN      93.0      75.0
# 2022-06-23     NaN      86.0      70.0
# 2022-06-24     NaN      96.0      69.0
# 2022-06-30     NaN       NaN       NaN
# 2023-04-11     NaN      83.0      39.0
#
# [681 rows x 3 columns]

# %%
core_weather["precip"].value_counts()
# Out:
# 0.00    6965
# 0.01     293
# 0.02     159
# 0.03     103
# 0.04      83
#         ...
# 2.46       1
# 2.90       1
# 4.12       1
# 2.04       1
# 2.23       1
# Name: precip, Length: 221, dtype: int64

# %%
core_weather["precip"]= core_weather["precip"].fillna(0)

# %%
core_weather[pd.isnull(core_weather["temp_min"])]
# Out:
#             precip  temp_max  temp_min
# DATE
# 1998-09-21    0.95       NaN       NaN
# 1999-03-10    0.00       NaN       NaN
# 2000-09-11    0.00       NaN       NaN
# 2001-04-06    0.00       NaN       NaN
# 2001-04-07    0.00       NaN       NaN
# 2001-04-08    0.00       NaN       NaN
# 2001-07-07    0.00       NaN       NaN
# 2001-09-20    0.00       NaN       NaN
# 2001-09-21    0.00       NaN       NaN
# 2001-09-22    0.00       NaN       NaN
# 2001-11-25    0.00       NaN       NaN
# 2001-11-26    0.00       NaN       NaN
# 2002-01-26    0.00       NaN       NaN
# 2002-01-27    0.00       NaN       NaN
# 2002-06-21    0.00       NaN       NaN
# 2002-12-30    0.00       NaN       NaN
# 2003-06-06    0.08       NaN       NaN
# 2004-12-01    0.00       NaN       NaN
# 2007-12-14    0.00       NaN       NaN
# 2007-12-15    0.00       NaN       NaN
# 2007-12-16    0.00       NaN       NaN
# 2007-12-17    0.00       NaN       NaN
# 2008-04-15    0.00       NaN       NaN
# 2008-06-12    0.00       NaN       NaN
# 2009-07-04    0.00       NaN       NaN
# 2011-02-17    0.00      73.0       NaN
# 2011-03-21    0.00      83.0       NaN
# 2011-06-03    0.00      94.0       NaN
# 2011-06-04    0.00       NaN       NaN
# 2011-07-20    0.00     105.0       NaN
# 2013-02-23    0.00       NaN       NaN
# 2018-01-11    0.30      50.0       NaN
# 2018-12-18    0.00      56.0       NaN
# 2019-03-30    0.00       NaN       NaN
# 2019-03-31    0.00       NaN       NaN
# 2022-06-12    0.00      95.0       NaN
# 2022-06-30    0.00       NaN       NaN

# %%
core_weather = core_weather.fillna(method="ffill")

# %%
core_weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# precip      0.0
# temp_max    0.0
# temp_min    0.0
# dtype: float64

# %%
core_weather.dtypes
# Out:
# precip      float64
# temp_max    float64
# temp_min    float64
# dtype: object

# %%
core_weather.index = pd.to_datetime(core_weather.index)

# %%
core_weather.index.year
# Out:
# Int64Index([1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996, 1996,
#             ...
#             2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023, 2023],
#            dtype='int64', name='DATE', length=9846)

# %%
core_weather.apply(lambda x: (x==9999).sum())
# Out:
# precip      0
# temp_max    0
# temp_min    0
# dtype: int64

# %%
core_weather[["temp_max","temp_min"]].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather["precip"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
core_weather.groupby(core_weather.index.year).sum()["precip"]
# Out:
# DATE
# 1996     0.00
# 1997     0.00
# 1998    35.80
# 1999    34.42
# 2000    24.06
# 2001    34.43
# 2002    20.95
# 2003    25.90
# 2004    35.11
# 2005    32.72
# 2006    25.07
# 2007    34.31
# 2008    34.55
# 2009    34.62
# 2010    25.86
# 2011    31.54
# 2012    21.96
# 2013    29.17
# 2014    24.04
# 2015    38.15
# 2016    34.46
# 2017    28.05
# 2018    22.78
# 2019    42.16
# 2020    36.84
# 2021    28.10
# 2022    29.33
# 2023    12.45
# Name: precip, dtype: float64

# %%
core_weather["target"] =core_weather.shift(-1)["temp_max"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1996-07-01    0.00      98.0      66.0   100.0
# 1996-07-02    0.00     100.0      66.0    92.0
# 1996-07-03    0.00      92.0      67.0    88.0
# 1996-07-04    0.00      88.0      68.0    91.0
# 1996-07-05    0.00      91.0      65.0    88.0
# ...            ...       ...       ...     ...
# 2023-06-27    0.03      90.0      61.0   103.0
# 2023-06-28    0.00     103.0      71.0    98.0
# 2023-06-29    0.00      98.0      74.0    97.0
# 2023-06-30    0.48      97.0      70.0    88.0
# 2023-07-01    0.12      88.0      66.0     NaN
#
# [9846 rows x 4 columns]

# %%
core_weather =core_weather.iloc[:-1,:].copy()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target
# DATE
# 1996-07-01    0.00      98.0      66.0   100.0
# 1996-07-02    0.00     100.0      66.0    92.0
# 1996-07-03    0.00      92.0      67.0    88.0
# 1996-07-04    0.00      88.0      68.0    91.0
# 1996-07-05    0.00      91.0      65.0    88.0
# ...            ...       ...       ...     ...
# 2023-06-26    0.00      92.0      54.0    90.0
# 2023-06-27    0.03      90.0      61.0   103.0
# 2023-06-28    0.00     103.0      71.0    98.0
# 2023-06-29    0.00      98.0      74.0    97.0
# 2023-06-30    0.48      97.0      70.0    88.0
#
# [9845 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge
reg = Ridge(alpha=.1)

# %%
predictors=["precip","temp_max","temp_min"]

# %%
train = core_weather.loc[:"2020-12-31"]

# %%
test = core_weather.loc["2021-01-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(test["target"], predictions)
# Out:
# 7.514012987454531

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)],axis=1)
combined.columns=["actual","predictions"]

# %%
combined
# Out:
#             actual  predictions
# DATE
# 2021-01-01    46.0    43.317664
# 2021-01-02    53.0    47.832919
# 2021-01-03    55.0    52.757371
# 2021-01-04    56.0    54.605800
# 2021-01-05    48.0    54.843326
# ...            ...          ...
# 2023-06-26    90.0    88.115056
# 2023-06-27   103.0    87.740896
# 2023-06-28    98.0    99.311451
# 2023-06-29    97.0    96.063756
# 2023-06-30    88.0    93.492034
#
# [911 rows x 2 columns]

# %%
combined.plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
reg.coef_
# Out:
# array([-2.35935602,  0.75254241,  0.17167231])

# %%
def create_predictions(predictors, core_weather, reg):
    train = core_weather.loc[:"2020-12-31"]
    test = core_weather.loc["2021-01-01":]
    reg.fit(train[predictors], train["target"])
    predictions = reg.predict(test[predictors])
    mean_absolute_error(test["target"], predictions)
    combined = pd.concat([test["target"], pd.Series(predictions, index=test.index)],axis=1)
    combined.columns=["actual","predictions"]
    return error, combined

# %%
core_weather["month_max"] = core_weather["temp_max"].rolling(30).mean()

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1997-04-09    0.00      38.0      27.0    36.0  61.933333       1.629825
# 1997-04-10    0.00      36.0      33.0    34.0  60.700000       1.686111
# 1997-04-11    0.00      34.0      26.0    37.0  59.633333       1.753922
# 1997-04-12    0.00      37.0      22.0    48.0  58.233333       1.573874
# 1997-04-13    0.00      48.0      25.0    62.0  57.800000       1.204167
# ...            ...       ...       ...     ...        ...            ...
# 2023-06-26    0.00      92.0      54.0    90.0  88.000000       0.956522
# 2023-06-27    0.03      90.0      61.0   103.0  88.266667       0.980741
# 2023-06-28    0.00     103.0      71.0    98.0  88.733333       0.861489
# 2023-06-29    0.00      98.0      74.0    97.0  88.900000       0.907143
# 2023-06-30    0.48      97.0      70.0    88.0  89.200000       0.919588
#
#              max_min
# DATE
# 1997-04-09  1.407407
# 1997-04-10  1.090909
# 1997-04-11  1.307692
# 1997-04-12  1.681818
# 1997-04-13  1.920000
# ...              ...
# 2023-06-26  1.703704
# 2023-06-27  1.475410
# 2023-06-28  1.450704
# 2023-06-29  1.324324
# 2023-06-30  1.385714
#
# [9565 rows x 7 columns]

# %%
core_weather["month_day_max"] = core_weather["month_max"] / core_weather["temp_max"]

# %%
core_weather["max_min"] = core_weather["temp_max"] / core_weather["temp_min"]

# %%
predictors = ["precip", "temp_max", "temp_min","month_max", "month_day_max", "max_min"]

# %%
core_weather
# Out:
#             precip  temp_max  temp_min  target  month_max  month_day_max  \
# DATE
# 1997-04-09    0.00      38.0      27.0    36.0  61.933333       1.629825
# 1997-04-10    0.00      36.0      33.0    34.0  60.700000       1.686111
# 1997-04-11    0.00      34.0      26.0    37.0  59.633333       1.753922
# 1997-04-12    0.00      37.0      22.0    48.0  58.233333       1.573874
# 1997-04-13    0.00      48.0      25.0    62.0  57.800000       1.204167
# ...            ...       ...       ...     ...        ...            ...
# 2023-06-26    0.00      92.0      54.0    90.0  88.000000       0.956522
# 2023-06-27    0.03      90.0      61.0   103.0  88.266667       0.980741
# 2023-06-28    0.00     103.0      71.0    98.0  88.733333       0.861489
# 2023-06-29    0.00      98.0      74.0    97.0  88.900000       0.907143
# 2023-06-30    0.48      97.0      70.0    88.0  89.200000       0.919588
#
#              max_min
# DATE
# 1997-04-09  1.407407
# 1997-04-10  1.090909
# 1997-04-11  1.307692
# 1997-04-12  1.681818
# 1997-04-13  1.920000
# ...              ...
# 2023-06-26  1.703704
# 2023-06-27  1.475410
# 2023-06-28  1.450704
# 2023-06-29  1.324324
# 2023-06-30  1.385714
#
# [9565 rows x 7 columns]

# %%
core_weather.apply(pd.isnull).sum()
# Out:
# precip           0
# temp_max         0
# temp_min         0
# target           0
# month_max        0
# month_day_max    0
# max_min          0
# dtype: int64

# %%
error, combined = create_predictions(predictors, core_weather, reg)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 error, combined = create_predictions(predictors, core_weather, reg)
#
# Cell In[62], line 4, in create_predictions(predictors, core_weather, reg)
#       2 train = core_weather.loc[:"2020-12-31"]
#       3 test = core_weather.loc["2021-01-01":]
# ----> 4 reg.fit(train[predictors], train["target"])
#       5 predictions = reg.predict(test[predictors])
#       6 mean_absolute_error(test["target"], predictions)
#
# File ~\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:1126, in Ridge.fit(self, X, y, sample_weight)
#    1123 self._validate_params()
#    1125 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
# -> 1126 X, y = self._validate_data(
#    1127     X,
#    1128     y,
#    1129     accept_sparse=_accept_sparse,
#    1130     dtype=[np.float64, np.float32],
#    1131     multi_output=True,
#    1132     y_numeric=True,
#    1133 )
#    1134 return super().fit(X, y, sample_weight=sample_weight)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~\anaconda3\lib\site-packages\sklearn\utils\validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains infinity or a value too large for dtype('float64').

# %%
core_weather = core_weather.iloc[29:,:].copy()
